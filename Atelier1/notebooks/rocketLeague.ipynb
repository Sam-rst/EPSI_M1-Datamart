# %%
import pandas as pd
import numpy as np
# import seaborn as sns

# %%
df_Game_players = pd.read_csv('../data/raw/games_by_players.csv').copy()
df_Game_team = pd.read_csv('../data/raw/games_by_teams.csv').copy()
df_main = pd.read_csv('../data/raw/main.csv').copy()
df_match_players = pd.read_csv('../data/raw/matches_by_players.csv').copy()
df_match_team = pd.read_csv('../data/raw/matches_by_teams.csv').copy()
df_players = pd.read_csv('../data/raw/players_db.csv').copy()
# Out:
# C:\Users\attis\AppData\Local\Temp\ipykernel_21304\3747949340.py:1: DtypeWarning: Columns (92) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Game_players = pd.read_csv('../data/raw/games_by_players.csv').copy()

# %%
df_Game_players.info()
df_Game_players.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106795 entries, 0 to 106794
# Columns: 103 entries, game_id to camera_transition_speed
# dtypes: bool(2), float64(87), int64(5), object(9)
# memory usage: 82.5+ MB
#                     game_id   color                   team_id team_region  \
# 0  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 1  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 2  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 3  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
# 4  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
# 5  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
# 6  616004f7143c37878b238697    blue  6020bc8ef1e4807cc700391a     Oceania
# 7  616004f7143c37878b238697    blue  6020bc8ef1e4807cc700391a     Oceania
# 8  616004f7143c37878b238697    blue  6020bc8ef1e4807cc700391a     Oceania
# ...

# %%
df_Game_team.info()
df_Game_team.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35594 entries, 0 to 35593
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   game_id                             35594 non-null  object
#  1   color                               35594 non-null  object
#  2   team_id                             35594 non-null  object
#  3   team_slug                           35594 non-null  object
#  4   team_name                           35594 non-null  object
#  5   team_region                         35555 non-null  object
#  6   ball_possession_time                34998 non-null  float64
#  7   ball_time_in_side                   34998 non-null  float64
#  8   core_shots                          35594 non-null  int64
#  9   core_goals                          35594 non-null  int64
#  10  core_saves                          35594 non-null  int64
# ...

# %%
df_main.info()
df_main.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18740 entries, 0 to 18739
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               18740 non-null  object
#  1   event                  18740 non-null  object
#  2   event_split            18740 non-null  object
#  3   event_region           18740 non-null  object
#  4   event_slug             18740 non-null  object
#  5   event_start_date       18740 non-null  object
#  6   event_end_date         18740 non-null  object
#  7   event_tier             18740 non-null  object
#  8   event_phase            18740 non-null  object
#  9   prize_money            18740 non-null  float64
#  10  stage_step             18740 non-null  int64
#  11  stage                  18740 non-null  object
#  12  stage_start_date       18740 non-null  object
#  13  stage_end_date         18740 non-null  object
# ...

# %%
df_match_players.info()
df_match_players.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26176 entries, 0 to 26175
# Data columns (total 90 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   match_id                                        26176 non-null  object
#  1   team_id                                         26176 non-null  object
#  2   team_region                                     26155 non-null  object
#  3   player_id                                       26176 non-null  object
#  4   player_tag                                      26176 non-null  object
#  5   core_shots                                      26176 non-null  float64
#  6   core_goals                                      26176 non-null  float64
#  7   core_saves                                      26176 non-null  float64
#  8   core_assists                                    26176 non-null  float64
# ...

# %%
df_match_team.info()
df_match_team.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10594 entries, 0 to 10593
# Data columns (total 54 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   match_id                            10594 non-null  object
#  1   color                               10594 non-null  object
#  2   team_id                             10594 non-null  object
#  3   team_slug                           10594 non-null  object
#  4   team_name                           10594 non-null  object
#  5   team_region                         10587 non-null  object
#  6   core_shots                          8708 non-null   float64
#  7   core_goals                          8708 non-null   float64
#  8   core_saves                          8708 non-null   float64
#  9   core_assists                        8708 non-null   float64
#  10  core_score                          8708 non-null   float64
# ...

# %%
df_players.info()
df_players.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_id       1218 non-null   object
#  1   player_slug     1218 non-null   object
#  2   player_tag      1218 non-null   object
#  3   player_name     511 non-null    object
#  4   player_country  1216 non-null   object
# dtypes: object(5)
# memory usage: 47.7+ KB
#                   player_id                                     player_slug  \
# 0  6284d6ccc437fde7e02d6e7b          https://octane.gg/players/6e7b-yasudon
# 1  60c46a3a9fc1a47e5f11199a            https://octane.gg/players/199a-2die4
# 2  5f3d8fdd95f40596eae241b7           https://octane.gg/players/41b7-2piece
# 3  61daef8bda9d7ca1c7ba3d33            https://octane.gg/players/3d33-3mari
# 4  62712944da9d7ca1c7badbfa            https://octane.gg/players/dbfa-47_vt
# ...
